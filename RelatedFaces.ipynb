# %% [markdown]
# <a href="https://colab.research.google.com/github/Neil-98/RelatedFaces/blob/master/RelatedFaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# Out:
# ...
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-hufm_uvg
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-hufm_uvg
# ...
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-cp36-none-any.whl size=8311 sha256=ca5482bdb66e466931d613b4f17312b425262d19e634bce0b4a1803d5f40577b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fjzf3ku6/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f5324442-0fcb-486f-bb3c-5732dfcc26e6" name="files[]" multiple disabled />
#      <output id="result-f5324442-0fcb-486f-bb3c-5732dfcc26e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"neilrex","key":"f96169d30dd03fe46c0765df79099d7d"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 63 Oct 24 10:30 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                      title                                               size  lastUpdated          downloadCount
# -------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# tristan581/17k-apple-app-store-strategy-games            17K Mobile Strategy Games                            8MB  2019-08-26 08:22:16           6389
# gustavomodelli/forest-fires-in-brazil                    Forest Fires in Brazil                              31KB  2019-08-24 16:09:16           7550
# akhilv11/border-crossing-entry-data                      Border Crossing Entry Data                           3MB  2019-08-21 14:51:34           2940
# rajeevw/ufcdata                                          UFC-Fight historical data from 1993 to 2019          2MB  2019-07-05 09:58:02           4222
# ...

# %%
# !kaggle competitions download -c recognizing-faces-in-the-wild -p /input
# Out:
# ...
#   0% 0.00/77.6k [00:00<?, ?B/s]
# 100% 77.6k/77.6k [00:00<00:00, 63.6MB/s]
# ...
#  50% 17.0M/34.1M [00:00<00:00, 58.1MB/s]
# 100% 34.1M/34.1M [00:00<00:00, 98.1MB/s]
# ...
#  83% 57.0M/68.6M [00:00<00:00, 46.6MB/s]
# 100% 68.6M/68.6M [00:01<00:00, 70.7MB/s]
# ...
#   0% 0.00/156k [00:00<?, ?B/s]
# 100% 156k/156k [00:00<00:00, 164MB/s]

# %%
cd ..
# Out:
# /

# %%
cd input
# Out:
# /input

# %%
ls
# Out:
# sample_submission.csv  test.zip  train_relationships.csv  train.zip

# %%
mkdir train

# %%
mv train.zip train/train.zip

# %%
mkdir test

# %%
mv test.zip test/test.zip

# %%
ls
# Out:
# sample_submission.csv  test/  train/  train_relationships.csv

# %%
cd train
# Out:
# /input/train

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#    creating: F0002/
#    creating: F0005/
#    creating: F0009/
#    creating: F0010/
#    creating: F0016/
#    creating: F0017/
#    creating: F0020/
#    creating: F0022/
#    creating: F0023/
#    creating: F0024/
#    creating: F0030/
#    creating: F0031/
#    creating: F0036/
#    creating: F0038/
#    creating: F0039/
#    creating: F0040/
#    creating: F0041/
#    creating: F0044/
#    creating: F0049/
#    creating: F0050/
#    creating: F0051/
#    creating: F0052/
#    creating: F0054/
#    creating: F0058/
#    creating: F0059/
#    creating: F0063/
#    creating: F0064/
#    creating: F0068/
#    creating: F0070/
#    creating: F0074/
#    creating: F0077/
#    creating: F0081/
#    creating: F0086/
#    creating: F0091/
#    creating: F0093/
#    creating: F0097/
#    creating: F0099/
#    creating: F0101/
#    creating: F0105/
#    creating: F0106/
#    creating: F0109/
#    creating: F0110/
#    creating: F0112/
#    creating: F0113/
# ...

# %%
cd ..
# Out:
# /input

# %%
cd test
# Out:
# /input/test

# %%
# !unzip test.zip
# Out:
# Archive:  test.zip
#   inflating: face00111.jpg
#   inflating: face04253.jpg
#   inflating: face05610.jpg
#   inflating: face05478.jpg
#   inflating: face05298.jpg
#   inflating: face02061.jpg
#   inflating: face03115.jpg
#   inflating: face04708.jpg
#   inflating: face00826.jpg
#   inflating: face03021.jpg
#   inflating: face04999.jpg
#   inflating: face00696.jpg
#   inflating: face01787.jpg
#   inflating: face00552.jpg
#   inflating: face04364.jpg
#   inflating: face03354.jpg
#   inflating: face01039.jpg
#   inflating: face01392.jpg
#   inflating: face01252.jpg
#   inflating: face04815.jpg
#   inflating: face03253.jpg
#   inflating: face00787.jpg
#   inflating: face01640.jpg
#   inflating: face02465.jpg
#   inflating: face00106.jpg
#   inflating: face00449.jpg
#   inflating: face02631.jpg
#   inflating: face05683.jpg
#   inflating: face04068.jpg
#   inflating: face01473.jpg
#   inflating: face00066.jpg
#   inflating: face03394.jpg
#   inflating: face01444.jpg
# ...

# %%
ls
# Out:
# face00000.jpg  face01257.jpg  face02514.jpg  face03771.jpg  face05028.jpg
# face00001.jpg  face01258.jpg  face02515.jpg  face03772.jpg  face05029.jpg
# face00002.jpg  face01259.jpg  face02516.jpg  face03773.jpg  face05030.jpg
# face00003.jpg  face01260.jpg  face02517.jpg  face03774.jpg  face05031.jpg
# face00004.jpg  face01261.jpg  face02518.jpg  face03775.jpg  face05032.jpg
# face00005.jpg  face01262.jpg  face02519.jpg  face03776.jpg  face05033.jpg
# face00006.jpg  face01263.jpg  face02520.jpg  face03777.jpg  face05034.jpg
# face00007.jpg  face01264.jpg  face02521.jpg  face03778.jpg  face05035.jpg
# face00008.jpg  face01265.jpg  face02522.jpg  face03779.jpg  face05036.jpg
# face00009.jpg  face01266.jpg  face02523.jpg  face03780.jpg  face05037.jpg
# face00010.jpg  face01267.jpg  face02524.jpg  face03781.jpg  face05038.jpg
# face00011.jpg  face01268.jpg  face02525.jpg  face03782.jpg  face05039.jpg
# face00012.jpg  face01269.jpg  face02526.jpg  face03783.jpg  face05040.jpg
# ...

# %%
cd ..
# Out:
# /input

# %%
cd ..
# Out:
# /

# %%
from collections import defaultdict
from glob import glob
from random import choice, sample

import cv2
import numpy as np
import pandas as pd
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Dense, Flatten, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, Add, Conv2D
from keras.models import Model
from keras.preprocessing import image
from keras.optimizers import Adam, Adagrad, RMSprop
from keras import regularizers
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace
import h5py
# Out:
# Using TensorFlow backend.

# %%
train_file_path = "../input/train_relationships.csv"
train_folders_path = "../input/train/"
val_famillies = "F09"

# %%
all_images = glob(train_folders_path + "*/*/*.jpg")
train_images = [x for x in all_images if val_famillies not in x]
val_images = [x for x in all_images if val_famillies in x]

# %%
len(all_images)
# Out:
# 12379

# %%
train_person_to_images_map = defaultdict(list)
ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]

for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# %%
relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values))
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]

# %%
len(relationships)
# Out:
# 3362

# %%
train = [x for x in relationships if val_famillies not in x[0]]
val = [x for x in relationships if val_famillies in x[0]]

# %%
len(train)
# Out:
# 3066

# %%
def read_img(path):
    img = image.load_img(path, target_size=(197, 197))
    img = np.array(img).astype(np.float)
    return preprocess_input(img, version=2)

# %%
def gen(list_tuples, person_to_images_map, batch_size=16):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size // 2)
        labels = [1] * len(batch_tuples)
        while len(batch_tuples) < batch_size:
            p1 = choice(ppl)
            p2 = choice(ppl)

            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
                batch_tuples.append((p1, p2))
                labels.append(0)

        for x in batch_tuples:
            if not len(person_to_images_map[x[0]]):
                print(x[0])

        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
        X1 = np.array([read_img(x) for x in X1])

        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
        X2 = np.array([read_img(x) for x in X2])

        yield [X1, X2], labels

# %%
def baseline_model():
    input_1 = Input(shape=(197, 197, 3))
    input_2 = Input(shape=(197, 197, 3))

    base_model = VGGFace(model='senet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = False

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x1_ = Multiply()([x1, x1])
    x2_ = Multiply()([x2, x2])
    x4 = Subtract()([x1_, x2_])
    x = Concatenate(axis=-1)([x4, x3])

    x = Dense(100, activation="relu")(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vgg_face.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

# %%
callbacks_list = [checkpoint, reduce_on_plateau]

# %%
model = baseline_model()
model.fit_generator(gen(train, train_person_to_images_map, batch_size=32), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=32), epochs=25, verbose=1,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=96, validation_steps=9)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
# updated model
def baseline_model2():
    input_1 = Input(shape=(197, 197, 3))
    input_2 = Input(shape=(197, 197, 3))

    base_model = VGGFace(model='senet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = False

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x = Concatenate()([x1, x2])
    x = Flatten()(x)
    x = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=RMSprop(lr=1e-4))

    model.summary()

    return model

# %%
file_path = "vgg_face2.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

# %%
callbacks_list = [checkpoint, reduce_on_plateau]

# %%
model2 = baseline_model2()
model2.fit_generator(gen(train, train_person_to_images_map, batch_size=32), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=32), epochs=25, verbose=1,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=96, validation_steps=48)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_10 (InputLayer)           (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# vggface_senet50 (Model)         multiple             26092144    input_10[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1, 1, 4096)   0           vggface_senet50[1][0]
#                                                                  vggface_senet50[2][0]
# ...

# %%
test_path = "../input/test/"

# %%
def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))


from tqdm import tqdm

submission = pd.read_csv('../input/sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model.predict([X1, X2]).ravel().tolist()
    predictions += pred

submission['is_related'] = predictions

submission.to_csv("vgg_face2.csv", index=False)
# Out:
# 166it [01:47,  1.57it/s]

# %%
from IPython.display import HTML
import base64
# function that takes in a dataframe and creates a text link to  
# download it (will only work for files < 2MB or so)
def create_download_link(df, title = "Download CSV file", filename = "submission.csv"):  
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)


create_download_link(submission)
# Out:
# <a download="submission.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
# model 3
def baseline_model3():
    input_1 = Input(shape=(197, 197, 3))
    input_2 = Input(shape=(197, 197, 3))

    base_model = VGGFace(model='senet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = False

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x = Concatenate()([x1, x2])
    x = Flatten()(x)
    x = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.0001))

    model.summary()

    return model

# %%
file_path = "vgg_face3.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

# %%
callbacks_list = [checkpoint, reduce_on_plateau]

# %%
model3 = baseline_model3()
model3.fit_generator(gen(train, train_person_to_images_map, batch_size=32), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=32), epochs=35, verbose=1,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=96, validation_steps=48)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# vggface_senet50 (Model)         multiple             26092144    input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 1, 4096)   0           vggface_senet50[1][0]
#                                                                  vggface_senet50[2][0]
# ...

# %%
test_path = "../input/test/"

# %%
def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))


from tqdm import tqdm

submission = pd.read_csv('../input/sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model3.predict([X1, X2]).ravel().tolist()
    predictions += pred

submission['is_related'] = predictions

submission.to_csv("vgg_face3.csv", index=False)
# Out:
# 166it [01:53,  1.11s/it]

# %%
# model 4
def baseline_model4():
    input_1 = Input(shape=(197, 197, 3))
    input_2 = Input(shape=(197, 197, 3))

    base_model = VGGFace(model='senet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = False

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x = Concatenate()([x1, x2])
    x = Flatten()(x)
    x = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00003))

    model.summary()

    return model

# %%
file_path = "vgg_face4.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

# %%
callbacks_list = [checkpoint, reduce_on_plateau]

# %%
model4 = baseline_model4()
model4.fit_generator(gen(train, train_person_to_images_map, batch_size=32), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=32), epochs=35, verbose=1,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=96, validation_steps=48)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
model4.fit_generator(gen(train, train_person_to_images_map, batch_size=32), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=32), epochs=15, verbose=1,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=96, validation_steps=48)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/15
# 96/96 [==============================] - 75s 784ms/step - loss: 4.6790 - acc: 0.7806 - val_loss: 4.6785 - val_acc: 0.7591
#
# Epoch 00001: val_acc improved from 0.75391 to 0.75911, saving model to vgg_face4.h5
# Epoch 2/15
# 96/96 [==============================] - 70s 726ms/step - loss: 4.5748 - acc: 0.7809 - val_loss: 4.5808 - val_acc: 0.7585
#
# Epoch 00002: val_acc did not improve from 0.75911
# Epoch 3/15
# 96/96 [==============================] - 70s 726ms/step - loss: 4.4995 - acc: 0.7708 - val_loss: 4.4855 - val_acc: 0.7474
#
# Epoch 00003: val_acc did not improve from 0.75911
# Epoch 4/15
# ...

# %%
# model 5
def baseline_model5(epochs = 35):
    input_1 = Input(shape=(197, 197, 3))
    input_2 = Input(shape=(197, 197, 3))

    base_model = VGGFace(model='senet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = False

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x = Concatenate()([x1, x2])
    x = Flatten()(x)
    x = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    adam = Adam(lr = 0.0001, decay = 0.0001/epochs)
    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer = adam)

    model.summary()

    return model

# %%
file_path = "vgg_face5.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

# %%
callbacks_list = [checkpoint, reduce_on_plateau]

# %%
model5 = baseline_model5(35)
model5.fit_generator(gen(train, train_person_to_images_map, batch_size=32), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=32), epochs=35, verbose=1,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=96, validation_steps=48)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# vggface_senet50 (Model)         multiple             26092144    input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 1, 4096)   0           vggface_senet50[1][0]
#                                                                  vggface_senet50[2][0]
# ...

# %%
test_path = "../input/test/"

# %%
def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))


from tqdm import tqdm

submission = pd.read_csv('../input/sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model4.predict([X1, X2]).ravel().tolist()
    predictions += pred

submission['is_related'] = predictions

submission.to_csv("vgg_face4.csv", index=False)
# Out:
# 166it [01:53,  1.15s/it]

# %%
from IPython.display import HTML
import base64
# function that takes in a dataframe and creates a text link to  
# download it (will only work for files < 2MB or so)
def create_download_link(df, title = "Download CSV file", filename = "submission.csv"):  
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)


create_download_link(submission)
# Out:
# <a download="submission.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
